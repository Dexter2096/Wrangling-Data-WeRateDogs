# %% [markdown]
# ### Introduction
#
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog.
#
# <br>WeRateDogs downloaded their Twitter archive and sent it to Udacity. The task was to gather, then assess and clean the data to presente this analyses and visualizations.

# %% [markdown]
# ### What is the distirbution of the rated dogs through the dog stages
#
# ![dog%20stages.PNG](attachment:dog%20stages.PNG)

# %% [markdown]
# ### What is the most common bread for the rated dogs according to the ML algorithim
# ![breed.PNG](attachment:breed.PNG)
#
# as shown in the graph the golden retriver is the most common

# %% [markdown]
# ### what is the avarge rating for the dogs
#
# #### After removing the outlier rating and rating bellow 1 (because they are good dog Brent ) the avarge rating was found to be 11.5 /10

# %% [markdown]
# ### is there a relation between retweet/ favourite count and the dog rating
#
# ![matrix.PNG](attachment:matrix.PNG)
#
# as shown in the table above no significant relation was found

# %% [markdown]
# ### Conclusion
# Warngling the data is a corner stone task in handling the data. in this project i was able to bring the data size from 592.2+ KB to 122.5+ KB while maitaing the majority of the useful information and we can see as we move to bigger data size the diffrance that could make. further more sometime the data cannot be trusted and need to be assesd before being analyzed to get a more trustworthy representaion of said data.
